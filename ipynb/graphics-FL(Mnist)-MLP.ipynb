# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import FuncFormatter

#1
# %run data/NIID-R-MNIST/FedAvg.ipynb
#2
# %run data/NIID-R-MNIST/POC.ipynb
#3
# %run data/NIID-R-MNIST/FedAvg-wOpt.ipynb
#4
# %run data/NIID-R-MNIST/POC-w_Opt.ipynb
#5
# %run data/NIID-R-MNIST/DFed-wOpt.ipynb

# %%
# %run aux/max_acc.ipynb
# Out:
# 0.8142866651217143 >> 8.478666543960568
# 0.7611000021298726 >> 13.797332843144739
# 0.8759333332379658 >> 2.3139997323354144
# 0.852566663424174 >> 4.650666713714601
# 0.89907333056132

# %%
# %run aux/acc.ipynb

# %%
# %run aux/loss.ipynb

# %%
# %run aux/energy.ipynb
# Out:
# 0.8491821435990923
# 0.6895245643632928
# 1.7521793525080267
# 1.5928960734566906
# 2.1588450060743583

# %%
bbox_y = 0.43
# %run aux/delay.ipynb

# %%
# %run aux/uploads.ipynb
