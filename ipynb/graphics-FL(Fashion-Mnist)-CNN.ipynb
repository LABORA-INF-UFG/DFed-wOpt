# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import FuncFormatter

#1
# %run data/NIID-R-FMNIST/FedAvg.ipynb
#2
# %run data/NIID-R-FMNIST/POC.ipynb
#3
# %run data/NIID-R-FMNIST/FedAvg-wOpt.ipynb
#4
# %run data/NIID-R-FMNIST/POC-w_Opt.ipynb
#5
# %run data/NIID-R-FMNIST/DFed-wOpt.ipynb

# %%
# %run aux/max_acc.ipynb
# Out:
# 0.781606662273407 >> 5.462275673361383
# 0.7350933313369751 >> 10.113608767004578
# 0.8262133280436198 >> 1.0016090963401059
# 0.7871666669845581 >> 4.906275202246279
# 0.8362294190070209

# %%
# %run aux/acc.ipynb

# %%
# %run aux/loss.ipynb

# %%
# %run aux/energy.ipynb
# Out:
# 1.5891695944248971
# 1.401827896030213
# 3.4661471281358063
# 3.365866251918096
# 4.2257685269658865

# %%
bbox_y = 0.01
# %run aux/delay.ipynb

# %%
# %run aux/uploads.ipynb
